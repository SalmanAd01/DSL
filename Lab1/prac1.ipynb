# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib.inline
# Out:
# UsageError: Line magic function `%matplotlib.inline` not found.

# %%
df = pd.read_csv("./datasets/employees.csv")
df.head()
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male  08-06-1993        12:42 PM   97308    6.945
# 1     Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male  03-04-2005         1:00 PM  138705    9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df.describe()
# Out:
#               Salary      Bonus %
# count    1000.000000  1000.000000
# mean    90662.181000    10.207555
# std     32923.693342     5.528481
# min     35013.000000     1.015000
# 25%     62613.000000     5.401750
# 50%     90428.000000     9.838500
# 75%    118740.250000    14.838000
# max    149908.000000    19.944000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         933 non-null    object
#  1   Gender             855 non-null    object
#  2   Start Date         1000 non-null   object
#  3   Last Login Time    1000 non-null   object
#  4   Salary             1000 non-null   int64
#  5   Bonus %            1000 non-null   float64
#  6   Senior Management  933 non-null    object
#  7   Team               957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df.columns[df.isna().any()].tolist()
# Out:
# ['First Name', 'Gender', 'Senior Management', 'Team']

# %%
df['Gender'].value_counts()
# Out:
# Female    431
# Male      424
# Name: Gender, dtype: int64

# %%
df['First Name'].isna().sum()
# Out:
# 67

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# First Name           0
# Gender               0
# Start Date           0
# Last Login Time      0
# Salary               0
# Bonus %              0
# Senior Management    0
# Team                 0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 764 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   First Name         764 non-null    object
#  1   Gender             764 non-null    object
#  2   Start Date         764 non-null    object
#  3   Last Login Time    764 non-null    object
#  4   Salary             764 non-null    int64
#  5   Bonus %            764 non-null    float64
#  6   Senior Management  764 non-null    object
#  7   Team               764 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 53.7+ KB

# %%
df['Team'].value_counts()
# Out:
# Business Development    88
# Client Services         85
# Product                 83
# Finance                 80
# Engineering             79
# Human Resources         76
# Marketing               74
# Sales                   72
# Legal                   67
# Distribution            60
# Name: Team, dtype: int64

# %%
df['Salary'].head()
# Out:
# 0     97308
# 2    130590
# 3    138705
# 4    101004
# 5    115163
# Name: Salary, dtype: int64

# %%
plt.plot(df['Salary'])

# %%
sns.displot(df['Salary'])

# %%
sns.distplot(df['Salary'])
# Out:
# C:\Users\exam\AppData\Local\Temp\ipykernel_3016\3249851952.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Salary'])
# <AxesSubplot: xlabel='Salary', ylabel='Density'>

# %%
df.head()
# Out:
#   First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male  08-06-1993        12:42 PM   97308    6.945
# 2      Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male  03-04-2005         1:00 PM  138705    9.340
# 4      Larry    Male   1/24/1998         4:47 PM  101004    1.389
# 5     Dennis    Male   4/18/1987         1:35 AM  115163   10.125
#
#   Senior Management             Team
# 0              True        Marketing
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services
# 5             False            Legal

# %%
df['Senior Management'].value_counts()
# Out:
# False    383
# True     381
# Name: Senior Management, dtype: int64

# %%
df['Bonus %'].value_counts()
# Out:
# 2.097     2
# 12.182    2
# 3.459     2
# 14.077    2
# 1.451     2
#          ..
# 19.930    1
# 4.035     1
# 10.717    1
# 16.443    1
# 10.169    1
# Name: Bonus %, Length: 751, dtype: int64

# %%
sns.distplot(df['Bonus %'])
# Out:
# C:\Users\exam\AppData\Local\Temp\ipykernel_3016\4294652916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Bonus %'])
# <AxesSubplot: xlabel='Bonus %', ylabel='Density'>

# %%
plt.plot(df['Start Date'])

# %%
df['Start Date'] = pd.to_datetime(df['Start Date'], errors='coerce')

# %%
df['Start Date'].dt.strftime('%m/%d/%Y')
# Out:
# 0      08/06/1993
# 2      04/23/1993
# 3      03/04/2005
# 4      01/24/1998
# 5      04/18/1987
#           ...
# 994    06/21/2013
# 996    01/31/1984
# 997    05/20/2013
# 998    04/20/2013
# 999    05/15/2012
# Name: Start Date, Length: 764, dtype: object

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42 PM   97308    6.945
# 2      Maria  Female 1993-04-23        11:17 AM  130590   11.858
# 3      Jerry    Male 2005-03-04         1:00 PM  138705    9.340
# 4      Larry    Male 1998-01-24         4:47 PM  101004    1.389
# 5     Dennis    Male 1987-04-18         1:35 AM  115163   10.125
#
#   Senior Management             Team
# 0              True        Marketing
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services
# 5             False            Legal

# %%
plt.plot(df['Start Date'])

# %%
sns.distplot(df['Start Date'])
# Out:
# C:\Users\exam\AppData\Local\Temp\ipykernel_3016\2153750782.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Start Date'])
# <AxesSubplot: xlabel='Start Date', ylabel='Density'>

# %%
df['Last Login Time'].value_counts()
# Out:
# 11:25 AM    4
# 4:56 PM     4
# 12:04 PM    4
# 1:35 PM     4
# 10:09 PM    4
#            ..
# 8:01 PM     1
# 1:48 AM     1
# 8:27 PM     1
# 2:20 AM     1
# 4:45 PM     1
# Name: Last Login Time, Length: 604, dtype: int64

# %%
sns.pairplot(df)
# Out:
# <__array_function__ internals>:200: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(), annot=True, cmap="RdYlGn")
# Out:
# C:\Users\exam\AppData\Local\Temp\ipykernel_3016\3209590085.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap="RdYlGn")
# <AxesSubplot: >

# %%
fig,ax = plt.subplots(ncols=6, nrows=2, figsize=(20,10))
ax = ax.flatten()
index = 0
for col,val in df.items():
    try:
        sns.distplot(val,ax=ax[index])
    except:
        pass
    index += 1
plt.tight_layout(pad=0.5,w_pad=0.7,h_pad=5.0)
# Out:
# C:\Users\exam\AppData\Local\Temp\ipykernel_3016\1604799137.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(val,ax=ax[index])
# C:\Users\exam\AppData\Local\Temp\ipykernel_3016\1604799137.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(val,ax=ax[index])
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()

# %%
scaled_features = df.copy()

# %%
col_names = ['Salary','Bonus %']
features = scaled_features[col_names]
scaler = StandardScaler().fit(features.values)
features = scaler.transform(features.values)

# %%
df[col_names] = features

# %%
df.head()
# Out:
#   First Name  Gender Start Date Last Login Time    Salary   Bonus %  \
# 0    Douglas    Male 1993-08-06        12:42 PM  0.209322 -0.571455
# 2      Maria  Female 1993-04-23        11:17 AM  1.222684  0.305074
# 3      Jerry    Male 2005-03-04         1:00 PM  1.469768 -0.144163
# 4      Larry    Male 1998-01-24         4:47 PM  0.321857 -1.562702
# 5     Dennis    Male 1987-04-18         1:35 AM  0.752967 -0.004111
#
#   Senior Management             Team
# 0              True        Marketing
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services
# 5             False            Legal

# %%
df['Gender'] = df['Gender'].replace([0,1],['Female','Male'],inplace=True)

# %%
df['Salary'].describe()
# Out:
# count    7.640000e+02
# mean    -9.765312e-17
# std      1.000655e+00
# min     -1.687420e+00
# 25%     -8.635422e-01
# 50%     -1.582167e-04
# 75%      8.416383e-01
# max      1.810874e+00
# Name: Salary, dtype: float64

# %%
df['Bonus %'].describe()
# Out:
# count    7.640000e+02
# mean     3.441110e-16
# std      1.000655e+00
# min     -1.629427e+00
# 25%     -8.839851e-01
# 50%     -8.733902e-02
# 75%      8.593946e-01
# max      1.747699e+00
# Name: Bonus %, dtype: float64

# %%
df.describe()
# Out:
#              Salary       Bonus %
# count  7.640000e+02  7.640000e+02
# mean  -9.765312e-17  3.441110e-16
# std    1.000655e+00  1.000655e+00
# min   -1.687420e+00 -1.629427e+00
# 25%   -8.635422e-01 -8.839851e-01
# 50%   -1.582167e-04 -8.733902e-02
# 75%    8.416383e-01  8.593946e-01
# max    1.810874e+00  1.747699e+00

# %% [markdown]
# ## Bi Varient

# %%
df.head()
# Out:
#   First Name Gender Start Date Last Login Time    Salary   Bonus %  \
# 0    Douglas   None 1993-08-06        12:42 PM  0.209322 -0.571455
# 2      Maria   None 1993-04-23        11:17 AM  1.222684  0.305074
# 3      Jerry   None 2005-03-04         1:00 PM  1.469768 -0.144163
# 4      Larry   None 1998-01-24         4:47 PM  0.321857 -1.562702
# 5     Dennis   None 1987-04-18         1:35 AM  0.752967 -0.004111
#
#   Senior Management             Team
# 0              True        Marketing
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services
# 5             False            Legal

# %%
sns.boxplot(df)
# Out:
# <AxesSubplot: >

# %%
sns.scatterplot(y=df['Last Login Time'],x=df['Team'])
# Out:
# <AxesSubplot: xlabel='Team', ylabel='Last Login Time'>

# %%
sns.scatterplot(y=df['Start Date'],x=df['Team'])
# Out:
# <AxesSubplot: xlabel='Team', ylabel='Start Date'>

# %%
pd.crosstab(df['Last Login Time'],df['Team'])
# Out:
# Team             Business Development  Client Services  Distribution  \
# Last Login Time
# 10:00 AM                            0                0             0
# 10:01 AM                            0                0             0
# 10:04 AM                            0                0             0
# 10:04 PM                            0                0             0
# 10:05 AM                            0                0             0
# ...                               ...              ...           ...
# 9:51 AM                             0                0             1
# 9:53 PM                             0                0             0
# 9:55 PM                             0                0             0
# 9:57 PM                             0                0             0
# 9:58 PM                             0                1             0
#
# Team             Engineering  Finance  Human Resources  Legal  Marketing  \
# Last Login Time
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
Y = df['Team']
X = df.drop(['Team','First Name','Last Login Time','Start Date'],axis=1)

# %%
Y.head()
# Out:
# 0          Marketing
# 2            Finance
# 3            Finance
# 4    Client Services
# 5              Legal
# Name: Team, dtype: object

# %%
X.head()
# Out:
#   Gender    Salary   Bonus % Senior Management
# 0   None  0.209322 -0.571455              True
# 2   None  1.222684  0.305074             False
# 3   None  1.469768 -0.144163              True
# 4   None  0.321857 -1.562702              True
# 5   None  0.752967 -0.004111             False

# %%
Y.value_counts()
# Out:
# Business Development    88
# Client Services         85
# Product                 83
# Finance                 80
# Engineering             79
# Human Resources         76
# Marketing               74
# Sales                   72
# Legal                   67
# Distribution            60
# Name: Team, dtype: int64

# %%
Y.unique()
# Out:
# array(['Marketing', 'Finance', 'Client Services', 'Legal', 'Product',
#        'Engineering', 'Business Development', 'Human Resources', 'Sales',
#        'Distribution'], dtype=object)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, cross_val_score
model_dict = dict()
def train_model(model,x,y):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
    model.fit(x_train, y_train)
    y_pred = model.p`redict(x_test)
    mse = mean_squared_error(y_test, y_pred)
    print("MSE: ", mse)
    print("R2: ", model.score(x_test, y_test))
    print("Accuracy: ", model.score(x_test, y_test))
    print("Actual value: ", y_test[0])
    print("Predicted value: ", y_pred[0])
    if model.score(x_test, y_test) >=0:
        print("Model is good")
        model_dict[model.__class__.__name__] = {"model":model,"Accuracy":model.score(x_test, y_test)}
    else:
        print("Model is bad")
